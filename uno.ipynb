# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Jaime Vargas / Economist

# %% [markdown]
# I am interested in Data Science because it is fun

# %% [markdown]
# This code sums finds the sum of all marks

# %%
marks = [70, 71, 73, 74, 77]

# find sum of all marks
total_marks = sum(marks)
print(total_marks)
# Out:
# 365

# %% [markdown]
# One
# Two
# * One
# * Two
# - Three
# - Four
# ![image.png](attachment:f63ede70-3cbb-4a89-a7df-b1ffe949c245.png)![image.png](attachment:6ac2bba2-23ba-4fd0-9c8f-6f676008d086.png)
